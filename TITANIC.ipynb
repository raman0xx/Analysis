# %%
import pandas as pd
import numpy as np

# %%
titan=pd.read_csv('dataset/titanic.csv')

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # How to find out total no. of records & columns?

# %%
titan.shape
# Out:
# (891, 12)

# %%
titan.shape[0]   #only rows
# Out:
# 891

# %%
titan.shape[1]   #only columns
# Out:
# 12

# %% [markdown]
# # How to find out all missing values count in all columns?

# %%
null=titan.isnull().sum()

# %%
null
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # How to show all missing age records?

# %%
titan[titan.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# # how to show all missing Embarked records?

# %%
titan[titan.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# # show total count survived or not survived passenger?

# %%
titan.value_counts(['Survived'])
# Out:
# Survived
# 0           549
# 1           342
# dtype: int64

# %% [markdown]
# # How to find out total count survived male & female passenger

# %%
titan[titan.Survived==1].Sex.value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %% [markdown]
# # How to find all passenger count which Fare=0 ?

# %%
titan[titan.Fare==0].value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                    Sex   Age   SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 264          0         1       Harrison, Mr. William   male  40.0  0      0      112059  0.0   B94    S           1
# 807          0         1       Andrews, Mr. Thomas Jr  male  39.0  0      0      112050  0.0   A36    S           1
# dtype: int64

# %% [markdown]
# # How many survived passenger count which Fare=0 ?

# %%
titan[(titan.Fare==0)&(titan.Survived==0)].value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                    Sex   Age   SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 264          0         1       Harrison, Mr. William   male  40.0  0      0      112059  0.0   B94    S           1
# 807          0         1       Andrews, Mr. Thomas Jr  male  39.0  0      0      112050  0.0   A36    S           1
# dtype: int64

# %% [markdown]
# # Show maximum fare only 3 passenger list ?

# %%
titan.sort_values('Fare',ascending=False)[:3]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C

# %% [markdown]
# # Show only 3 columns with maximum fare 3 passenger list ?

# %%
a=titan.sort_values('Fare',ascending=False).index[:3]
a
# Out:
# Int64Index([258, 737, 679], dtype='int64')

# %%
titan.iloc[a,[0,4,9]]
# Out:
#      PassengerId     Sex      Fare
# 258          259  female  512.3292
# 737          738    male  512.3292
# 679          680    male  512.3292

# %%
titan.sample(7)
# Out:
#      PassengerId  Survived  Pclass  \
# 269          270         1       1
# 135          136         0       2
# 839          840         1       1
# 41            42         0       2
# 79            80         1       3
# 358          359         1       3
# 728          729         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 269                             Bissette, Miss. Amelia  female  35.0      0
# 135                                 Richard, Mr. Emile    male  23.0      0
# 839                               Marechal, Mr. Pierre    male   NaN      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# 358                               McGovern, Miss. Mary  female   NaN      0
# 728                    Bryhl, Mr. Kurt Arnold Gottfrid    male  25.0      1
#
#      Parch         Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # All missing Embarked data rows dropped ?

# %%
b=titan[titan.Embarked.isnull()]

# %%
b
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ###  all missing data row dropped

# %%
b.dropna()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# # all missing Age values replace with NaN to -1 ?

# %%
a=titan.Age.fillna(-1)

# %% [markdown]
# # show all records which Fare b/w 0 to <100

# %%
titan[(titan.Fare<100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
