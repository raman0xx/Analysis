# %% [markdown]
# # Working with date_time in Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/ufo.csv')

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
#In this csv file data, Time column data is string format, so converts # into date and time format

# %%
df['Time']=pd.to_datetime(df.Time)

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time
# 0     1930-06-01 22:00:00
# 1     1930-06-30 20:00:00
# 2     1931-02-15 14:00:00
# 3     1931-06-01 13:00:00
# 4     1933-04-18 19:00:00
# ...

# %%
df.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df.Time.dt.year
# Out:
# 0        1930
# 1        1930
# 2        1931
# 3        1931
# 4        1933
#          ...
# 18236    2000
# 18237    2000
# 18238    2000
# 18239    2000
# 18240    2000
# Name: Time, Length: 18241, dtype: int64

# %%
df.Time.dt.month
# Out:
# 0         6
# 1         6
# 2         2
# 3         6
# 4         4
#          ..
# 18236    12
# 18237    12
# 18238    12
# 18239    12
# 18240    12
# Name: Time, Length: 18241, dtype: int64

# %%
df.Time.dt.day
# Out:
# 0         1
# 1        30
# 2        15
# 3         1
# 4        18
#          ..
# 18236    31
# 18237    31
# 18238    31
# 18239    31
# 18240    31
# Name: Time, Length: 18241, dtype: int64

# %%
df.Time.dt.hour
# Out:
# 0        22
# 1        20
# 2        14
# 3        13
# 4        19
#          ..
# 18236    23
# 18237    23
# 18238    23
# 18239    23
# 18240    23
# Name: Time, Length: 18241, dtype: int64

# %%
df.Time.dt.day_name()
# Out:
# 0         Sunday
# 1         Monday
# 2         Sunday
# 3         Monday
# 4        Tuesday
#           ...
# 18236     Sunday
# 18237     Sunday
# 18238     Sunday
# 18239     Sunday
# 18240     Sunday
# Name: Time, Length: 18241, dtype: object

# %%
df.Time.dt.day_name().value_counts()
# Out:
# Tuesday      2822
# Sunday       2689
# Saturday     2687
# Friday       2669
# Thursday     2598
# Wednesday    2476
# Monday       2300
# Name: Time, dtype: int64

# %%
df.shape
# Out:
# (18241, 5)

# %% [markdown]
# # new column add time

# %%
df['Week_Days']=df.Time.dt.day_name()

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days
# 0     1930-06-01 22:00:00    Sunday
# 1     1930-06-30 20:00:00    Monday
# 2     1931-02-15 14:00:00    Sunday
# 3     1931-06-01 13:00:00    Monday
# ...

# %%
import matplotlib.pyplot as plt

# %%
df[df.Week_Days.isin(['Sunday','Saturday'])].Week_Days.value_counts().plot(kind='bar',cmap='cool')
plt.grid()

# %%
df.Week_Days.value_counts()
# Out:
# Tuesday      2822
# Sunday       2689
# Saturday     2687
# Friday       2669
# Thursday     2598
# Wednesday    2476
# Monday       2300
# Name: Week_Days, dtype: int64

# %%
df.Week_Days.value_counts().plot(kind='bar',cmap='hot')
plt.grid()

# %%
p=pd.to_datetime('1991/1/30')

# %%
p
# Out:
# Timestamp('1991-01-30 00:00:00')

# %%
df[df.Time>=p]
# Out:
#                       City Colors Reported Shape Reported State  \
# 6501             Quartzite             RED          LIGHT    AZ
# 6502   Washington Township             NaN          OTHER    NJ
# 6503                 Selma             NaN      RECTANGLE    CA
# 6504             Calistoga             NaN         SPHERE    CA
# 6505              Lakewood             NaN         CIRCLE    CO
# ...                    ...             ...            ...   ...
# 18236           Grant Park             NaN       TRIANGLE    IL
# 18237          Spirit Lake             NaN           DISK    IA
# 18238          Eagle River             NaN            NaN    WI
# 18239          Eagle River             RED          LIGHT    WI
# 18240                 Ybor             NaN           OVAL    FL
#
#                      Time Week_Days
# 6501  1991-02-01 20:00:00    Friday
# 6502  1991-02-11 14:00:00    Monday
# 6503  1991-02-14 22:00:00  Thursday
# 6504  1991-02-15 15:00:00    Friday
# ...

# %% [markdown]
# # 0,3,4 is a column index. [Only 3 columns records show]

# %%
index=df[df.Time>=p].index.tolist()
df.iloc[index,[0,3,4]].head()                  # kyuki index m string data store kiya hua hai maine ,Not run
# Out:
#                      City State                Time
# 6501            Quartzite    AZ 1991-02-01 20:00:00
# 6502  Washington Township    NJ 1991-02-11 14:00:00
# 6503                Selma    CA 1991-02-14 22:00:00
# 6504            Calistoga    CA 1991-02-15 15:00:00
# 6505             Lakewood    CO 1991-02-15 19:00:00

# %% [markdown]
# # How to find next 6 months records of given date:-

# %%
t=pd.to_datetime('1999/6/30')

# %%
df[(df.Time>=p)&(df.Time<=t)]
# Out:
#                       City Colors Reported Shape Reported State  \
# 6501             Quartzite             RED          LIGHT    AZ
# 6502   Washington Township             NaN          OTHER    NJ
# 6503                 Selma             NaN      RECTANGLE    CA
# 6504             Calistoga             NaN         SPHERE    CA
# 6505              Lakewood             NaN         CIRCLE    CO
# ...                    ...             ...            ...   ...
# 13798          Navajo Lake             NaN          CIGAR    NM
# 13799           Pennsauken             NaN          LIGHT    NJ
# 13800         New Carlisle             NaN            NaN    IN
# 13801              Phoenix             NaN      RECTANGLE    AZ
# 13802          Shingletown        RED BLUE         CIRCLE    CA
#
#                      Time  Week_Days
# 6501  1991-02-01 20:00:00     Friday
# 6502  1991-02-11 14:00:00     Monday
# 6503  1991-02-14 22:00:00   Thursday
# 6504  1991-02-15 15:00:00     Friday
# ...

# %%
df.State.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days
# 0     1930-06-01 22:00:00    Sunday
# 1     1930-06-30 20:00:00    Monday
# 2     1931-02-15 14:00:00    Sunday
# 3     1931-06-01 13:00:00    Monday
# ...

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days
# 0     1930-06-01 22:00:00    Sunday
# 1     1930-06-30 20:00:00    Monday
# 2     1931-02-15 14:00:00    Sunday
# 3     1931-06-01 13:00:00    Monday
# ...

# %%
df.Time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
df.Time.min()
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
df.head(1)
# Out:
#      City Colors Reported Shape Reported State                Time Week_Days
# 0  Ithaca             NaN       TRIANGLE    NY 1930-06-01 22:00:00    Sunday

# %%
df.tail(1)
# Out:
#        City Colors Reported Shape Reported State                Time Week_Days
# 18240  Ybor             NaN           OVAL    FL 2000-12-31 23:59:00    Sunday

# %%
df[df.Time.dt.year.isin(range(1989,2000))].Time.dt.year.value_counts().plot(kind='bar')
plt.show()

# %%
df['Year']=df.Time.dt.year

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days  Year
# 0     1930-06-01 22:00:00    Sunday  1930
# 1     1930-06-30 20:00:00    Monday  1930
# 2     1931-02-15 14:00:00    Sunday  1931
# ...

# %%
df['Date']=df.Time.dt.date

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days  Year        Date
# 0     1930-06-01 22:00:00    Sunday  1930  1930-06-01
# 1     1930-06-30 20:00:00    Monday  1930  1930-06-30
# ...

# %%
df['Months']=df.Time.dt.month

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days  Year        Date  Months
# 0     1930-06-01 22:00:00    Sunday  1930  1930-06-01       6
# ...

# %%
df['Hours']=df.Time.dt.hour

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days  Year        Date  Months  Hours
# 0     1930-06-01 22:00:00    Sunday  1930  1930-06-01       6     22
# ...

# %%
df['Minutes']=df.Time.dt.minute

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days  Year        Date  Months  Hours  Minutes
# 0     1930-06-01 22:00:00    Sunday  1930  1930-06-01       6     22        0
# ...

# %%
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time Week_Days  Year        Date  Months  Hours  Minutes
# 0     1930-06-01 22:00:00    Sunday  1930  1930-06-01       6     22        0
# ...
